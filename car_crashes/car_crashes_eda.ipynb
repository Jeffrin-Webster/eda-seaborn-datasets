# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('car_crashes')
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
#What is the shape of the dataset?

# %%
df.shape
# Out:
# (51, 8)

# %%
#Are there missing values?

# %%
df.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
#Which state has the highest number of total crashes?

# %%
df[df['total'] == df['total'].max()]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 40   23.9     9.082    9.799          22.944       19.359       858.97
#
#     ins_losses abbrev
# 34      109.72     ND
# 40      116.29     SC

# %%
#Which state has the lowest alcohol related accidents?

# %%
df[df['alcohol'] == df['alcohol'].min()]
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 8    5.9     2.006    1.593             5.9          5.9      1273.89
#
#    ins_losses abbrev
# 8      136.05     DC

# %%
#What is the average insurance premium?

# %%
df['ins_premium'].mean()
# Out:
# 886.9576470588235

# %%
#What is the correlation between total accidents and alcohol use?

# %%
df[['total', 'alcohol']].corr()
# Out:
#             total   alcohol
# total    1.000000  0.852613
# alcohol  0.852613  1.000000

# %%
#Which state pays the highest insurance premium?

# %%
df[df['ins_premium'] == df['ins_premium'].max()]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
#
#     ins_losses abbrev
# 30      159.85     NJ

# %%
# Which state has the highest insurance losses?

# %%
df[df['ins_losses'] == df['ins_losses'].max()]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 18   20.5     7.175    6.765          14.965        20.09      1281.55
#
#     ins_losses abbrev
# 18      194.78     LA

# %%
# List top 5 states with the most alcohol-related crashes.

# %%
df.sort_values(by='alcohol', ascending=False).head()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 40   23.9     9.082    9.799          22.944       19.359       858.97
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 43   19.4     7.760    7.372          17.654       16.878      1004.75
# 11   17.5     9.450    7.175          14.350       15.225       861.18
#
#     ins_losses abbrev
# 34      109.72     ND
# 40      116.29     SC
# 26       85.15     MT
# 43      156.83     TX
# 11      120.92     HI

# %%
# Do states with higher insurance premiums have fewer accidents?

# %%
sns.scatterplot(data=df, x='ins_premium', y='total')
# Out:
# <Axes: xlabel='ins_premium', ylabel='total'>

# %%
# Visualize relationship: ins_losses vs total crashes

# %%
df[(df['total'] < df['total'].mean()) & (df['ins_premium'] > df['ins_premium'].mean())]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 20   12.5     4.250    4.000           8.875       12.375      1048.78
# 21    8.2     1.886    2.870           7.134        6.560      1011.14
# 22   14.1     3.384    3.948          13.395       10.857      1110.61
# 28   14.7     5.439    4.704          13.965       14.553      1029.87
# 30   11.2     1.792    3.136           9.632        8.736      1301.52
# 32   12.3     3.936    3.567          10.824        9.840      1234.31
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 47   10.6     4.452    3.498           8.692        9.116       890.03
#
#     ins_losses abbrev
# 6       167.02     CT
# 8       136.05     DC
# 10      142.80     GA
# ...
